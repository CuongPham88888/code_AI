# %% [markdown]
# <a href="https://colab.research.google.com/github/CuongPham88888/code_AI/blob/main/food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop,Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/mon_an/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 160 images belonging to 10 classes.

# %%
validation=train_datagen.flow_from_directory('/content/drive/MyDrive/mon_an/validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 30 images belonging to 10 classes.

# %%
training_set.class_indices
# Out:
# {'banh_bot_loc': 0,
#  'banh_can': 1,
#  'banh_trang': 2,
#  'ca_nguoi_dại_duong': 3,
#  'ca_tam': 4,
#  'dau_hu': 5,
#  'dau_phong': 6,
#  'keo_duong': 7,
#  'nem_chua': 8,
#  'sun_ga': 9}

# %%
model=Sequential()
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 150, 150, 32)      896
#
#  conv2d_7 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d_3 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_9 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 37, 37, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 37, 37, 128)       147584
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 41472)             0
#
#  dense_2 (Dense)             (None, 128)               5308544
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 5,596,842
# Trainable params: 5,596,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt=SGD(lr=0.01,momentum=0.9)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(training_set,epochs=100,batch_size=64,verbose=1, validation_data=validation, callbacks=[EarlyStopping(monitor='val_loss', patience=20)]) # verbose=1 để hiển thị quá trinh học
# Out:
# Epoch 1/100
# 5/5 [==============================] - 60s 13s/step - loss: 7.5501 - accuracy: 0.1437 - val_loss: 2.3814 - val_accuracy: 0.1000
# Epoch 2/100
# 5/5 [==============================] - 24s 5s/step - loss: 2.3261 - accuracy: 0.1063 - val_loss: 2.2860 - val_accuracy: 0.1000
# Epoch 3/100
# 5/5 [==============================] - 24s 5s/step - loss: 2.2704 - accuracy: 0.1000 - val_loss: 2.2994 - val_accuracy: 0.1000
# Epoch 4/100
# 5/5 [==============================] - 24s 5s/step - loss: 2.1928 - accuracy: 0.1937 - val_loss: 2.0545 - val_accuracy: 0.3000
# Epoch 5/100
# 5/5 [==============================] - 24s 5s/step - loss: 2.0807 - accuracy: 0.2562 - val_loss: 1.9788 - val_accuracy: 0.2000
# Epoch 6/100
# 5/5 [==============================] - 24s 5s/step - loss: 1.9147 - accuracy: 0.2438 - val_loss: 1.6585 - val_accuracy: 0.4667
# Epoch 7/100
# 5/5 [==============================] - 25s 5s/step - loss: 1.6545 - accuracy: 0.3875 - val_loss: 1.2518 - val_accuracy: 0.6667
# Epoch 8/100
# 5/5 [==============================] - 24s 5s/step - loss: 1.4904 - accuracy: 0.4500 - val_loss: 1.2703 - val_accuracy: 0.5000
# Epoch 9/100
# 5/5 [==============================] - 24s 5s/step - loss: 1.5137 - accuracy: 0.4625 - val_loss: 1.2653 - val_accuracy: 0.7333
# Epoch 10/100
# 5/5 [==============================] - 24s 5s/step - loss: 1.4128 - accuracy: 0.5437 - val_loss: 0.9780 - val_accuracy: 0.8333
# Epoch 11/100
# 5/5 [==============================] - 25s 5s/step - loss: 1.2228 - accuracy: 0.5813 - val_loss: 0.9345 - val_accuracy: 0.6667
# Epoch 12/100
# 5/5 [==============================] - 24s 5s/step - loss: 1.1976 - accuracy: 0.5750 - val_loss: 0.9216 - val_accuracy: 0.7000
# Epoch 13/100
# 5/5 [==============================] - 24s 5s/step - loss: 1.0881 - accuracy: 0.6375 - val_loss: 0.9472 - val_accuracy: 0.6333
# Epoch 14/100
# 5/5 [==============================] - 24s 5s/step - loss: 1.0510 - accuracy: 0.6313 - val_loss: 0.6433 - val_accuracy: 0.8000
# Epoch 15/100
# 5/5 [==============================] - 24s 5s/step - loss: 0
100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1967 - accuracy: 0.9312 - val_loss: 0.1925 - val_accuracy: 0.9667
# Epoch 51/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1599 - accuracy: 0.9375 - val_loss: 0.1715 - val_accuracy: 0.8667
# Epoch 52/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.2797 - accuracy: 0.9250 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1771 - accuracy: 0.9438 - val_loss: 0.0719 - val_accuracy: 0.9667
# Epoch 54/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0611 - accuracy: 0.9875 - val_loss: 0.0488 - val_accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0850 - accuracy: 0.9625 - val_loss: 0.0365 - val_accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0700 - accuracy: 0.9750 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0535 - accuracy: 0.9875 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1943 - accuracy: 0.9625 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0553 - accuracy: 0.9875 - val_loss: 0.0885 - val_accuracy: 0.9667
# Epoch 60/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.2331 - accuracy: 0.9312 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1215 - accuracy: 0.9375 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0570 - accuracy: 0.9812 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 63/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0813 - accuracy: 0.9688 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1203 - accuracy: 0.9750 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0606 - accuracy: 0.9812 - val_loss: 0.1002 - val_accuracy: 0.9667
# Epoch 66/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1054 - accuracy: 0.9625 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0957 - accuracy: 0.9812 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1211 - accuracy: 0.9563 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0587 - accuracy: 0.9812 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0581 - accuracy: 0.9812 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1111 - accuracy: 0.9875 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0334 - accuracy: 0.9875 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1019 - accuracy: 0.9750 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0964 - accuracy: 0.9625 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.2284 - accuracy: 0.9312 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1145 - accuracy: 0.9500 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0755 - accuracy: 0.9812 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0948 - accuracy: 0.9688 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 25s 5s/step - loss: 0.0312 - accuracy: 0.9875 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 25s 5s/step - loss: 0.0342 - accuracy: 0.9875 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0418 - accuracy: 0.9688 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0466 - accuracy: 0.9937 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0560 - accuracy: 0.9937 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1046 - accuracy: 0.9812 - val_loss: 8.5529e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 9.2407e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0206 - accuracy: 0.9875 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0234 - accuracy: 0.9937 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0325 - accuracy: 0.9937 - val_loss: 1.1820e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0807 - accuracy: 0.9812 - val_loss: 0.0345 - val_accuracy: 0.9667
# Epoch 94/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1153 - accuracy: 0.9500 - val_loss: 0.0646 - val_accuracy: 0.9667
# Epoch 95/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1895 - accuracy: 0.9438 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1908 - accuracy: 0.9500 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1137 - accuracy: 0.9625 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1007 - accuracy: 0.9563 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.1132 - accuracy: 0.9500 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 24s 5s/step - loss: 0.0823 - accuracy: 0.9688 - val_loss: 0.2507 - val_accuracy: 0.9667

# %%
# Đánh giá độ chính xác của mô hình sau khi đã train 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.023406056687235832
# Train Accuracy 0.9937499761581421

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Lưu lại
model.save("Final.h5")

# %%
model_CNN=load_model('Final.h5')

# %%
img=load_img("/content/drive/MyDrive/mon_an/test/banhbotloc/z3430079720965_72158e2c9f6e6ce7d4b18190005ca99e.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='banh_bot_loc'
if round(result[0][1])==1:
  prediction='banh_can'
if round(result[0][2])==1:
  prediction='banh_trang'
if round(result[0][3])==1:
  prediction='ca_nguoi_dai_duong'
if round(result[0][4])==1:
  prediction='ca_tam'
if round(result[0][5])==1:
  prediction='dau_hu'
if round(result[0][6])==1:
  prediction='dau_phong'
if round(result[0][7])==1:
  prediction='keo_duong'
if round(result[0][8])==1:
  prediction='nem_chua'
if round(result[0][9])==1:
  prediction='sun_ga'
print(prediction)
# Out:
# banh_bot_loc
