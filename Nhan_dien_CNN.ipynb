# %% [markdown]
# <a href="https://colab.research.google.com/github/CuongPham88888/code_AI/blob/main/Nhan_dien_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop,Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/BAITAP/HINH/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 142 images belonging to 3 classes.

# %%
validation=train_datagen.flow_from_directory('/content/drive/MyDrive/BAITAP/HINH/validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 32 images belonging to 3 classes.

# %%
training_set.class_indices
# Out:
# {'cuong': 0, 'dat': 1, 'quoc': 2}

# %%
model=Sequential()
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 150, 150, 32)      896
#
#  conv2d_7 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d_3 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_9 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 37, 37, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 37, 37, 128)       147584
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 41472)             0
#
#  dense_2 (Dense)             (None, 128)               5308544
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 5,595,939
# Trainable params: 5,595,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt=SGD(lr=0.01,momentum=0.9)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af4e39733c1a> in <module>()
# ----> 1 model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])
#
# NameError: name 'model' is not defined

# %%
history=model.fit(training_set,epochs=100,batch_size=64,verbose=1, validation_data=validation, callbacks=[EarlyStopping(monitor='val_loss', patience=20)]) # verbose=1 để hiển thị quá trinh học
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 540ms/step - loss: 9.2191 - accuracy: 0.4014 - val_loss: 0.7400 - val_accuracy: 0.5000
# Epoch 2/100
# 5/5 [==============================] - 2s 353ms/step - loss: 0.8376 - accuracy: 0.5563 - val_loss: 0.5286 - val_accuracy: 0.6875
# Epoch 3/100
# 5/5 [==============================] - 2s 419ms/step - loss: 0.3776 - accuracy: 0.9225 - val_loss: 0.0897 - val_accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 2s 350ms/step - loss: 0.6336 - accuracy: 0.7958 - val_loss: 1.1102 - val_accuracy: 0.8125
# Epoch 5/100
# 5/5 [==============================] - 2s 404ms/step - loss: 1.2686 - accuracy: 0.7746 - val_loss: 0.2823 - val_accuracy: 0.8125
# Epoch 6/100
# 5/5 [==============================] - 2s 437ms/step - loss: 0.3242 - accuracy: 0.9366 - val_loss: 0.0738 - val_accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 2s 415ms/step - loss: 0.1242 - accuracy: 0.9648 - val_loss: 0.4098 - val_accuracy: 0.8750
# Epoch 8/100
# 5/5 [==============================] - 2s 344ms/step - loss: 0.4101 - accuracy: 0.8521 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 2s 358ms/step - loss: 0.2034 - accuracy: 0.9296 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 2s 415ms/step - loss: 0.1160 - accuracy: 0.9577 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 2s 340ms/step - loss: 0.0531 - accuracy: 0.9859 - val_loss: 0.0457 - val_accuracy: 0.9688
# Epoch 12/100
# 5/5 [==============================] - 2s 352ms/step - loss: 0.0997 - accuracy: 0.9859 - val_loss: 0.0502 - val_accuracy: 0.9688
# Epoch 13/100
# 5/5 [==============================] - 2s 344ms/step - loss: 0.0242 - accuracy: 0.9930 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 2s 357ms/step - loss: 0.1633 - accuracy: 0.9859 - val_loss: 8.7479e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 2s 340ms/step - loss: 0.0328 - accuracy: 0.9859 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 2s 352ms/step - loss: 0.0113 - accuracy: 0.9930 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 2s 406ms/step - loss: 0.0564 - accuracy: 0.9789 - val_loss: 4.3473e-06 - val_accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 2s 350ms/step - loss: 0.1270 - accuracy: 0.9507 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 2s 358ms/step - loss: 0.0444 - accuracy: 0.9859 - val_loss: 5.0878e-04 - val_accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 2s 338ms/step - loss: 0.0345 - accuracy: 0.9930 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 2s 337ms/step - loss: 0.0745 - accuracy: 0.9789 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 2s 341ms/step - loss: 0.0224 - accuracy: 0.9930 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 2s 357ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 2s 344ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 5.2203e-04 - val_accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 2s 350ms/step - loss: 0.0308 - accuracy: 0.9930 - val_loss: 1.3979e-04 - val_accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 2s 404ms/step - loss: 0.0799 - accuracy: 0.9930 - val_loss: 8.7136e-05 - val_accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 2s 355ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.5829e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 2s 343ms/step - loss: 0.0155 - accuracy: 0.9930 - val_loss: 2.3879e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 2s 344ms/step - loss: 0.0159 - accuracy: 0.9930 - val_loss: 7.2633e-05 - val_accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 2s 345ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.5688e-05 - val_accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 2s 336ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.7649e-05 - val_accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 2s 337ms/step - loss: 0.0089 - accuracy: 0.9930 - val_loss: 3.6736e-05 - val_accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 2s 343ms/step - loss: 2.4092e-04 - accuracy: 1.0000 - val_loss: 3.1378e-05 - val_accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 2s 342ms/step - loss: 1.1194e-04 - accuracy: 1.0000 - val_loss: 2.5204e-05 - val_accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 2s 347ms/step - loss: 3.4055e-04 - accuracy: 1.0000 - val_loss: 9.9053e-06 - val_accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 2s 346ms/step - loss: 3.4123e-04 - accuracy: 1.0000 - val_loss: 1.7392e-05 - val_accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 2s 351ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.6302e-04 - val_accuracy: 1.0000

# %%
# Đánh giá độ chính xác của mô hình sau khi đã train 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.00024146783107426018
# Train Accuracy 1.0

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Lưu lại
model.save("Final.h5")

# %%
model_CNN=load_model('Final.h5')

# %%
img=load_img("/content/Cuong.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='cuong'
if round(result[0][1])==1:
  prediction='dat'
if round(result[0][2])==1:
  prediction='quoc'
print(prediction)
# Out:
# cuong
